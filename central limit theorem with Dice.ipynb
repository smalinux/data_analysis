# %% [markdown]
# [https://machinelearningmastery.com/a-gentle-introduction-to-the-central-limit-theorem-for-machine-learning/](https://machinelearningmastery.com/a-gentle-introduction-to-the-central-limit-theorem-for-machine-learning/)

# %%
# generate random dice rolls
from numpy.random import seed
from numpy.random import randint
from numpy import mean
from matplotlib import pyplot
# seed the random number generator
seed(1)

# %%
# generate a sample (50 observation) of die rolls
rolls = randint(1, 7, 50)
print(rolls)
print(mean(rolls))
# Out:
# [4 5 4 1 3 5 6 3 4 1 6 4 1 2 2 2 4 6 3 3 5 4 4 1 5 3 5 3 5 5 6 6 2 6 4 2 3
#  5 2 6 4 3 4 4 5 2 4 6 3 6]
# 3.84

# %%
# calculate the mean of 50 dice rolls 1000 times
means = [mean(randint(1, 7, 50)) for _ in range(1000)]
# plot the distribution of sample means
pyplot.hist(means)
pyplot.show()
