# %%
import pandas as pd

# %%
df = pd.read_excel('./data/Store_Sales.xlsx')

# %% [markdown]
# # change column format from: 4 number (68.5100) to 2 numbers (68.51)

# %%
# before
df['Sales'].head()
# Out:
# 0     165.4300
# 1      16.0072
# 2      68.5100
# 3    1531.1700
# 4     111.1944
# Name: Sales, dtype: float64

# %%
# df['Sales'] = df['Sales'].map('{:,.2f}'.format) ### In-place
df['foo'] = df['Sales'].map('{:,.2f}'.format)
df['foo'].head()
# Out:
# 0      165.43
# 1       16.01
# 2       68.51
# 3    1,531.17
# 4      111.19
# Name: foo, dtype: object

# %% [markdown]
# # Second level sorting
# برتب الداتا بناء على عمودين: او two levels
# المستوى الأول هو التاريخ عادى: مثلا من اقدم تاريخ لاحدث تاريخ
# كدا هيكون عندنا مبيعات كتيره لكل يوم والايام مترتبه من الاقدم للاحدث.
# المستوى الثانى عايز الـ rows تترتب من الاكثر مبيعاً للاقل مبيعا.
# عملتها

# %%
df = pd.read_excel('./data/Store_Sales.xlsx')
df.sort_values(['Order Date', 'Sales'], ascending=[True, False])
# Out:
#       Order ID Order Date Order Priority  Order Quantity      Sales  \
# 7983     13729 2016-01-01  Not Specified               9   933.5500
# 6840     28774 2016-01-01           High              32   192.9900
# 2389     37537 2016-01-02            Low              32  5245.5500
# 7437     37537 2016-01-02            Low              43  4369.0133
# 26       37537 2016-01-02            Low               4  1325.7900
# ...        ...        ...            ...             ...        ...
# 5223     47815 2019-12-30  Not Specified              45   621.6300
# 4114     50950 2019-12-30  Not Specified              35   479.4670
# 5978     50950 2019-12-30  Not Specified               6   418.5000
# 6210     25542 2019-12-30            Low              37   275.4800
# 3857     45127 2019-12-30         Medium              10    15.1405
#
#            Ship Mode  Shipping Cost          Province Customer Segment  \
# 7983     Express Air           37.5            Quebec      Home Office
# ...
